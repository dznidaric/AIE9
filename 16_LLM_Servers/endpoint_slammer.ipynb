# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
""" os.environ["HTTPS_PROXY"] = "http://user:pass@192.168.255.60:8080"
os.environ["HTTP_PROXY"] = "http://user:pass@192.168.255.60:8080"
os.environ["https_proxy"] = "http://user:pass@192.168.255.60:8080"
os.environ["http_proxy"] = "http://user:pass@192.168.255.60:8080"
 """

# %%
# maknut se s vpn-a i pokrenut

os.environ["HTTPS_PROXY"] = ""
os.environ["HTTP_PROXY"] = ""
os.environ["https_proxy"] = ""
os.environ["http_proxy"] = ""

# %%
from langchain_fireworks import ChatFireworks

model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint, timeout=15)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000236029725D0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000023604EBB750>
# That classic tongue‑twister doesn’t have a definitive answer—people have made all sorts of guesses for fun.  If you want a “scientifically inspired” take: a study by the New Zealand Forest Research Institute estimated a burrowing marsupial’s shoulder‑wrest energy could move about **700 pounds (≈320 kg)** of wood in a single day if it could chuck it, on a best‑case scenario.  In other words, a woodchuck could chuck **800‑odd bits of wood** happily—provided it keeps up with its cozy burrow!
#
# But for the spirit of the rhyme, the most common reply is:
# > **“A woodchuck would chuck as much wood as a woodchuck could chuck if a woodchuck could chuck wood!”**

# %%
response
# Out:
# AIMessage(content='That classic tongue‑twister doesn’t have a definitive answer—people have made all sorts of guesses for fun.  If you want a “scientifically inspired” take: a study by the New Zealand Forest Research Institute estimated a burrowing marsupial’s shoulder‑wrest energy could move about **700 pounds (≈320\u202fkg)** of wood in a single day if it could chuck it, on a best‑case scenario.  In other words, a woodchuck could chuck **800‑odd bits of wood** happily—provided it keeps up with its cozy burrow!  \n\nBut for the spirit of the rhyme, the most common reply is:  \n> **“A woodchuck would chuck as much wood as a woodchuck could chuck if a woodchuck could chuck wood!”**', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 88, 'total_tokens': 397, 'completion_tokens': 309}, 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'fireworks', 'model_name': 'accounts/fireworks/models/gpt-oss-20b'}, id='lc_run--019cd9f7-536f-7eb2-baba-4cfb9841e87c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 88, 'output_tokens': 309, 'total_tokens': 397})

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 24 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-030eed8d97564d758a947a1467153941"}
# Request 3 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-83a015d4da1e4d8fa0b3805d4024017b"}
# Request 10 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-05214e70768143ed9d0b1888d3e4bd8c"}
# Request 19 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-9a8b39bd2b004719888d1958f9a851ef"}
# Request 5 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-afe7f56ec2e7498ca09ba3f6c351f80a"}
# Request 9 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-1f10ae9b775d44bfb195eaa9dc51aded"}
# Request 18 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-eed03a848347400abe97c1a356c75b27"}
# Request 16 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-e8a24ae5f293422dbbb833d1b923f210"}
# Request 21 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-e5e248cbfd4c4f5bb76c08463d07d658"}
# Request 6 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-748e7df1e62944e4933051aed30e2d11"}
# Response 22: A wood‑chuck, in a forest clause,
# Wields the physics of to...
# Response 12: A classic tongue‑twister, the answer is usually given as a w...
# Response 2: If a wood‑chuck could actually chuck wood, the answer is… *a...
# Response 23: **Answer (Request 23)**
# > “How much wood could a wood‑chuc...
# Response 11: That old tongue‑twister never actually has a definitive, mea...
# Response 1: A woodchuck would chuck as much wood as a woodchuck would ch...
# Response 14: **Answer:**
# Classic folklore (and the tongue‑twister itsel...
# Response 20: **(Request #20)**
#
# *How much wood could a wood‑chuck chuck...
# Response 13: The old tongue‑twister is more of a playful rhyme than an ex...
# Response 7: The classic tongue‑twister answer is:
#
# > **“A wood‑chuck wo...
# Response 17: The classic tongue‑twister “How much wood would a woodchuck ...
# Response 4: The classic tongue‑twister doesn’t actually give us a hard n...
# Response 8: The classic tongue‑twister has been around for over a centur...
# Response 15: Here are **15** whimsical (and a few surprisingly thoughtful...
